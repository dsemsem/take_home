# %% [markdown]
# # Part 1: Query Annotation
#
# Identify patterns in the data and create labels to group similar keywords.
#
# - Feel free to edit the spreadsheet as needed (re-sort, add columns etc.)
# - Summarize your findings. This should include
#     - a description of each group
#     - % of total keywords that each group contains
#     - any other notes/observations about the data or your methods for selecting the groups

# %% [markdown]
# ## Transforming the data ##
# After recieving the xlsx file, I added some cursory column labels. I want to use pandas multiindexing to index the queries by language and search intent. I added the language manually using [ISO 2 letter language codes](https://www.sitepoint.com/iso-2-letter-language-codes/), and read the file into this notebook.

# %%
import pandas as pd
pd.set_option('display.max_rows', 10)
df = pd.read_excel('THED_ISOCoded.xlsx', sheet_name = 'Part 1 Queries')
df
# Out:
#                              query keyword intent likely user intent language  \
# 0                  baixar whatsapp              N  Download Whatsapp       PT
# 1        options trading beginners             IV      Get more info       EN
# 2              stainless steel pan              T                NaN       EN
# 3             cheap auto insurance             IV                NaN       EN
# 4          chase credit card login            NaN                NaN       EN
# ..                             ...            ...                ...      ...
# 245                    新車 軽 自動車 価格            NaN                NaN       JP
# 246      plumbing services near me            NaN                NaN       EN
# 247           arthritus treatments            NaN                NaN       EN
# 248              voyage dinnerware            NaN                NaN       EN
# 249  will i qualify for a mortgage            NaN                NaN       EN
#
#           translation
# 0    download whatapp
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 245               NaN
# 246               NaN
# 247               NaN
# 248               NaN
# 249               NaN
#
# [250 rows x 5 columns]

# %% [markdown]
# ## Next I create a new data frame, indexing by language. ##
# Then I write the new data frame to a new xlsx file.

# %%
# applying the .sort_index function to group and list the indexes alphabetically
multi = df.set_index(['language']).sort_index()
multi
# Out:
#                                 query keyword intent likely user intent  \
# language
# DE        aktueller heizöl tagespreis            NaN                NaN
# DE              privatverkauf wohnung            NaN                NaN
# DE          autohandel gebrauchtwagen            NaN                NaN
# DE         mieter für wohnung gesucht            NaN                NaN
# DE           steuererklärung formular            NaN                NaN
# ...                               ...            ...                ...
# PT                    jogar minecraft            NaN                NaN
# PT              pepper trees for sale            NaN                NaN
# PT              geladeira em promoção            NaN                NaN
# PT        transmissão ao vivo futebol            NaN                NaN
# PT                    baixar whatsapp              N  Download Whatsapp
#
#                translation
# language
# DE                     NaN
# DE                     NaN
# DE                     NaN
# DE                     NaN
# DE                     NaN
# ...                    ...
# PT                     NaN
# PT                     NaN
# PT                     NaN
# PT                     NaN
# PT        download whatapp
#
# [250 rows x 4 columns]

# %%
'''
multi.to_excel("THED_LangInd.xlsx")
'''

# %% [markdown]
# ## I did some quick translations...
# Indexing by language first made it easy for me to quickly translate non-English langauge queries using a combination of Google Translate, my own abilities, and online research. These translations were helpful for labeling the search intent.
#
# I labeled the search intent myself based on what I thought the dominant intent would be. Then I wrote my progress to a new spreadsheet.

# %%
language_index_df = pd.read_excel('THED_LangInd.xlsx')
search_index_df = language_index_df.set_index(['language', 'search intent']).sort_index()
search_index_df
# Out:
#                                                  query likely user intent  \
# language search intent
# DE       Commercial              privatverkauf wohnung                NaN
#          Commercial          wohnungsvermietung privat                NaN
#          Informational     aktueller heizöl tagespreis                NaN
#          Informational      mieter für wohnung gesucht                NaN
#          Informational  trauertexte für beileidskarten                NaN
# ...                                                ...                ...
# PT       Navigational                  baixar whatsapp  Download Whatsapp
#          Navigational             meracdo livre brasil                NaN
#          Transactional     emitir boleto pagamento mei                NaN
#          Transactional                 jogar minecraft                NaN
#          Transactional           geladeira em promoção                NaN
#
#                                                               translation
# language search intent
# DE       Commercial                                private sale apartment
#          Commercial                              apartment rental private
#          Informational                    Current heating oil daily price
#          Informational                        tenant wanted for apartment
#          Informational                  mourning texts for sympathy cards
# ...                                                                   ...
# PT       Navigational                                    download whatapp
#          Navigational                                  live market Brazil
#          Transactional  issue mei(Micro Etreprenuer Individual) paymen...
#          Transactional                                     play Minecraft
#          Transactional                                     fridge on sale
#
# [250 rows x 3 columns]

# %%
'''
search_index_df.to_excel('THED_SearchInd.xlsx')
'''

# %% [markdown]
# ## More annotations ##
# I decided to nonexhaustively add [Google Product Taxonomy](https://developers.google.com/google-ads/api/reference/data/codes-formats#expandable-15) in a new column via spreadsheets before reading the file back into the notebook. Assuming the data is representative of a larger set, these categories could represent the products and services that are most relevent to user's queries.
#
# I especially focus on Commercial and Transactional search intents. Informational queries required much more interpretation. In the interset of time I excluded them.

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_colwidth', 0)
product_codes_df = pd.read_excel('THED_SearchInd.xlsx',
                           # the kwarg 'index_col' allows me to retain multiindexing across pandas & spreadsheets
                          index_col=[0,1])
# reapplying .sort_index function to correct and re-sort any categorical errors fixed using the spreadsheet
product_codes_df = product_codes_df.sort_index()
product_codes_df
# Out:
#                                                                                                                                                                                                                                                                                                                    query  \
# language search intent
# DE       Commercial     privatverkauf wohnung
#          Commercial     wohnungsvermietung privat
#          Informational  aktueller heizöl tagespreis
#          Informational  mieter für wohnung gesucht
#          Informational  trauertexte für beileidskarten
#          Informational  zugverbindungen von nach
#          Navigational   autohandel gebrauchtwagen
#          Navigational   steuererklärung formular
#          Navigational   pcr test in meiner nähe
#          Navigational   das örtliche telefonnummer
# EN       Commercial     ap automation software
#          Commercial     purple maxi skirt
#          Commercial     top consulting firms
#          Commercial     best online it schools
#          Commercial     vehicle self storage
#          Commercial     antivirus software trial
#          Commercial     los angeles business internet providers
#          Commercial     outdoor rug stripes
#          Commercial     patio furniture set
#          Commercial     vacuum cleaners
#          Commercial     best online savings account interest rates
#          Commercial     personal loans
#          Commercial     customer data support platform
#          Commercial     lg frontload stainless steel
#          Commercial     massage therapist profiles
#          Commercial     luxury travel companies
#          Commercial     voyage dinnerware
#          Commercial     leather aviator jackets for men
#          Commercial     hugo boss suits
#          Commercial     bigelow raspberry tea
#          Commercial     digital marketing services online
#          Commercial     online certification programs
#          Commercial     best crm software for hotels
#          Commercial     whirlpool 36 in french door refrigerator
#          Commercial     accredited online college degree programs
#          Commercial     best payroll software
#          Commercial     sign up for bank account online
#          Commercial     work timesheet app
#          Commercial     anxiety meds without rx
#          Commercial     assisted living lafayette
#          Commercial     who accepts davis vision
#          Commercial     belt racks for closets
#          Commercial     video conference services
#          Commercial     los angeles business internet
#          Commercial     bad debt consolidation
#          Commercial     divorce attorney
#          Commercial     ergonomic office chair
#          Commercial     dining table pad covers
#          Commercial     juice mp3
#          Commercial     senior living
#          Commercial     online mba programs for international students
#          Commercial     small business bank account
#          Commercial     accredited online degrees
#          Commercial     small business management software
#          Commercial     commercial patio furniture
#          Commercial     walk in bath prices
#          Commercial     best security system for home
#          Commercial     mortgage preapproval
#          Commercial     logo maker
#          Commercial     wordpress ecommerce
#          Commercial     cobalt blue jumpsuit
#          Commercial     xanax canadian pharmacy
#          Commercial     carry on luggage with wheels
#          Commercial     best gaming laptop
#          Commercial     it cosmetics concealer
#          Commercial     best online savings accounts
#          Commercial     compare online college degrees
#          Commercial     online money lenders for bad credit
#          Commercial     auto moving company
#          Commercial     stainless steel pan
#          Commercial     juice mp3
#          Commercial     data recovery service
#          Commercial     rebar cutting tools
#          Commercial     best tax debt relief services
#          Commercial     air purifiers
#          Commercial     payment processing system
#          Commercial     debt reduction services
#          Commercial     cheap lawyers
#          Commercial     individual dental and vision insurance
#          Commercial     shop bowflex treadmill
#          Commercial     dental implants
#          Commercial     54 outdoor bench cushion
#          Commercial     bank account online
#          Commercial     best mba programs
#          Commercial     auto insurance companies
#          Commercial     who has best tire deals
#          Commercial     looking for a malpractice lawyer
#          Commercial     pdf reader
#          Commercial     bankruptcy credit counseling
#          Commercial     dinnerware birds
#          Commercial     batteries for stereo
#          Commercial     white casual pants
#          Commercial     garden hose
#          Commercial     pastry board marble
#          Commercial     car donation
#          Informational  how does alexa work
#          Informational  online advertising earn money
#          Informational  when your lower back hurts
#          Informational  tornado in nc
#          Informational  keto diet food list pdf
#          Informational  gout symtoms
#          Informational  the size of a cell is limited by the ____.
#          Informational  current chicago lakefront temperature
#          Informational  what you need to know about flipping houses
#          Informational  how long does heroin stay in your system
#          Informational  will i qualify for a mortgage
#          Informational  digital transformation model
#          Informational  what causes low white cell count
#          Informational  heart attacksymptoms
#          Informational  math
#          Informational  what should my sugar level be
#          Informational  is the post office open today
#          Informational  pros and cons of annuities
#          Informational  what are symptoms of ms disease
#          Informational  10 day forecast kent
#          Informational  why does a company go public
#          Informational  how do i lease a car
#          Informational  what causes tremors in hands
#          Informational  pictures of bed bug bits
#          Informational  what time does target close
#          Informational  how do you treat afib
#          Informational  what is normal cholestrol level
#          Informational  how to remove red wine stain
#          Informational  what is amyloidosis symptoms
#          Informational  what helps severe constipation
#          Informational  how can i make money quick
#          Informational  how low is too low for bp
#          Informational  what causes low red cell count
#          Informational  nasdaq etf
#          Informational  do i need to take consent of my husband to take my 8year old son abroad for a job  & as i have filed for  a divorce & its in process
#          Informational  do credit cards work
#          Informational  stomach pains chart
#          Informational  what is the temperature in las vegas in mid may
#          Informational  does kaiser cover hearing aids
#          Informational  temperature in tampa
#          Informational  is it better to own or lease a car
#          Informational  29829 weather
#          Informational  then compute : payback period, and decision if the policy of accepting project is &lt; 1.5 year. accounting rate of return decision if both projects are independent. net present value decision if both projects are independent. benefit cost ratio decision if both projects are independent.
#          Informational  does norco make you gain weight
#          Informational  san pedro cactus
#          Informational  Five Day Precipitation Forecast Map Tennessee
#          Informational  where is my stimulas check
#          Informational  is there
#          Informational  how depressed are you quiz
#          Informational  options trading beginners
#          Informational  temperature in cancun in July
#          Informational  what is a squamous cell
#          Informational  volunteer organizations
#          Informational  how to make amphetamine sulphate at home
# ...
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          NEI            NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
# ES       Commercial     dining table set 4 chairs
#          Informational  locate your retirement fund
#          Informational  print Federal Taxpayer Registration
#          Informational  divorce certificate
#          Informational  cover letter template
#          Navigational   check your electricity bill
#          Navigational   Mexican passport
#          Navigational   stars channel live
#          Transactional  free certified birth certificate
#          Transactional  download vix
#          Transactional  free technical courses
#          Transactional  passport for the first time or renewal
#          Transactional  get your birth certificate online
# JA       Commercial     car insurance direct
#          Commercial     Tokyo electricity contract
#          Commercial     on-site surveillance camera
#          Commercial     cheap flight tickets cheapest
#          Commercial     new light car price
#          Informational  add gmail account
#          Navigational   free tv tver
#          Navigational   Fighters broadcast free
#          Navigational   DoCoMo cellphone online shop
#          Transactional  free unzipping software
# NEI      Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          NEI            NaN
# PT       Commercial     Nike shoes
#          Navigational   live soccer broadcast
#          Navigational   download whatapp
#          Navigational   live market Brazil
#          Transactional  issue mei(Micro Etreprenuer Individual) payment slip
#          Transactional  play Minecraft
#          Transactional  fridge on sale

# %% [markdown]
# ## Splitting the taxonomies ##
# I want to make the document more usable programatically and in spreadsheets. I decided to break the taxonomies up by levels. I will have to write a function to iterate over my list of codes and split them using ' / ' as a delimiter to make a new list of arrays.

# %%
#filtering out my NaN values
taxonomy_df = product_codes_df[product_codes_df['Google Ads API product/service category'].notnull()]
#creating a list from the filtered product taxonomies
taxonomy_list = taxonomy_df['Google Ads API product/service category'].tolist()
# this is my list of taxonomies
taxonomy_list
# Out:
# ['/Real Estate/Real Estate Listings/Rental Listings/Apartment Rentals',
#  '/Real Estate/Real Estate Listings/Rental Listings/Apartment Rentals',
#  '/Business & Industrial/Energy Industry/Oil & Gas/Fuel/Natural Gas',
#  '/Real Estate/Real Estate Listings/Rental Listings/Apartment Rentals ',
#  '/Occasions & Gifts/Special Occasions/Funerals & Bereavement',
#  '/Travel & Tourism/Transportation & Excursions/Bus & Rail Services/Rail Services',
#  '/Vehicles/Motor Vehicles/Used Motor Vehicles',
#  '/Finance/Accounting & Auditing/Tax Preparation & Planning',
#  '/Health/Health Care Services/Laboratory Testing & Medical Diagnostic Services',
#  '/Internet & Telecom/Internet/Directories & Listings/Phone & Address Directories',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Accounting & Financial Software',
#  "/Apparel/Clothing/Women's Clothing/Skirts",
#  'NEI',
#  '/Jobs & Education/Jobs & Careers/Job Listings/IT & Technical Jobs',
#  '/Real Estate/Relocation & Household Moving/Storage Rental Services',
#  '/Computers & Consumer Electronics/Computers/Software/Internet Software & Web Goodies/Network Security Software/Anti-Virus Software',
#  '/Internet & Telecom/Internet/Internet Service Plans',
#  '/Home & Garden/Yard, Garden & Patio/Yard & Patio Furniture & Accessories',
#  '/Home & Garden/Yard, Garden & Patio/Yard & Patio Furniture & Accessories',
#  '/Home & Garden/Home Appliances/Floor Cleaners & Accessories/Vacuum Cleaners & Accessories',
#  '/Finance/Investing/Interest Free & Tax-Deferred Savings Accounts',
#  '/Finance/Credit & Lending/Loans/Personal Lending & Borrowing/Personal Loans & Lines of Credit',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Business Management Software/Customer Service & Support Software',
#  '/Home & Garden/Home Appliances/Laundry Room Appliances/Washers & Dryers',
#  '/Health/Health Care Services/Wellness Therapy & Massage/Massage & Relaxation Services',
#  '/Travel & Tourism/Luxury Travel',
#  '/Home & Garden/Kitchen & Dining/Kitchen Utensils & Gadgets',
#  '/Apparel/Clothing/Sport Coats & Jackets',
#  '/Apparel/Clothing/Suits & Business Attire',
#  '/Food & Groceries/Beverages/Non-Alcoholic Beverages/Tea',
#  '/Business & Industrial/Business Management/Advertising & Marketing/Internet Marketing',
#  '/Jobs & Education/Education & Training/Training & Certification',
#  '/Business & Industrial/Business Management/Customer Support & Outreach',
#  '/Home & Garden/Home Appliances/Major Kitchen Appliances/Refrigerators & Freezers',
#  'Online Education & Degree Programs',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Accounting & Financial Software',
#  '/Finance/Banking/Online Banking',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Accounting & Financial Software/Time Management & Time Tracking Software',
#  '/Health/Health Conditions & Concerns/Mental Health/Mental Health Medications/Anxiety-Relief Medications',
#  '/Health/Health Care Services/Geriatric & Aging Care Services/Assisted Living Services',
#  '/Health/Health Care Services/Vision Services/Eye Exams & Optometry',
#  '/Home & Garden/Home Furniture/Bedroom Furniture/Clothing & Shoe Storage',
#  '/Internet & Telecom/Teleconferencing',
#  '/Internet & Telecom/Internet/Internet Service Plans',
#  '/Finance/Credit & Lending/Debt Management & Consolidation',
#  '/Law & Government/Legal/Family Law/Divorce Law',
#  '/Business & Industrial/Office/Office Furniture/Task Chairs',
#  '/Home & Garden/Home Furniture/Kitchen & Dining Room Furniture/Kitchen & Dining Room Tables',
#  '/Arts & Entertainment/Music & Audio/Pop Music',
#  '/Health/Health Care Services/Geriatric & Aging Care Services/Retirement Homes & Senior Living Communities',
#  '/Jobs & Education/Education & Training/Online Education & Degree Programs',
#  '/Finance/Banking/Bank Accounts',
#  '/Jobs & Education/Education & Training/Online Education & Degree Programs',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Business Management Software/',
#  '/Real Estate/Property Development/Commercial Property Development',
#  '/Business & Industrial/Building Construction & Maintenance/Plumbing/Plumbing Fixtures/Bathroom Fixtures/Bathtubs',
#  '/Home & Garden/Home Safety & Security',
#  '/Finance/Credit & Lending/Loans/Home Loans & Mortgages',
#  '/Business & Industrial/Design & Engineering/Graphic Design',
#  '/Business & Industrial/Business Management/E-Commerce',
#  '/Apparel/Clothing/Outerwear',
#  '/Health/Health Conditions & Concerns/Mental Health/Mental Health Medications/Anxiety-Relief Medications',
#  '/Travel & Tourism/Luggage & Travel Accessories/Luggage/Carry-On Bags',
#  '/Computers & Consumer Electronics/Computers/Computer Hardware/Gaming Computers',
#  '/Beauty & Personal Care/Make-Up & Cosmetics/Concealer',
#  '/Finance/Banking/Online Banking',
#  '/Jobs & Education/Education & Training/Online Education & Degree Programs',
#  '/Finance/Credit & Lending/Loans/Bad Credit & No Credit Credit & Lending',
#  '/Real Estate/Relocation & Household Moving/Consumer Vehicle Shipping Services',
#  '/Home & Garden/Kitchen & Dining/Cookware & Cookware Sets/Pots & Pans',
#  '/Arts & Entertainment/Music & Audio/Pop Music',
#  '/Computers & Consumer Electronics/Computers/Computer Repair/Data Recovery',
#  '/Business & Industrial/Industrial Goods & Manufacturing/Industrial Manufacturing/Industrial Cutting',
#  '/Finance/Credit & Lending/Debt Management & Consolidation',
#  '/Home & Garden/Home Appliances',
#  '/Business & Industrial/Retail Trade/Merchant Services & Payment Systems',
#  '/Finance/Credit & Lending/Debt Management & Consolidation',
#  '/Law & Government/Legal/Attorneys & Law Firms',
#  '/Finance/Insurance/Health Insurance',
#  '/Sports & Fitness/Fitness/Fitness Equipment & Accessories/Fitness & Weight Training Machines/Treadmills',
#  '/Health/Health Care Services/Dentists & Dental Services/Orthodontists & Orthodontic Services',
#  '/Home & Garden/Yard, Garden & Patio/Yard & Patio Furniture & Accessories',
#  '/Finance/Banking/Online Banking',
#  '/Jobs & Education/Education & Training/Colleges, Universities & Post-Secondary Education/Graduate Programs/MBA Programs',
#  '/Finance/Insurance/Vehicle Insurance/Car Insurance',
#  '/Vehicles/Vehicle Parts & Accessories/Vehicle Tires & Tire Parts',
#  '/Law & Government/Legal/Attorneys & Law Firms',
#  '/Computers & Consumer Electronics/Computers/Software/Software Utilities',
#  '/Finance/Credit & Lending/Credit Counseling',
#  '/Home & Garden/Kitchen & Dining/Plates & Serving Dishes',
#  '/Computers & Consumer Electronics/Consumer Electronics/Consumer Electronic Accessories/Batteries & Chargers',
#  '/Apparel/Clothing/Pants, Jeans & Trousers',
#  '/Hobbies & Leisure/Gardening/Yard & Garden Accessories',
#  '/Home & Garden/Kitchen & Dining/Bakeware',
#  '/Vehicles/Vehicle Donation & Removal',
#  '/Computers & Consumer Electronics/Consumer Electronics/Wireless Devices',
#  '/Business & Industrial/Business Management/Advertising & Marketing/Internet Marketing',
#  '/Health/Health Conditions & Concerns/Headache & Pain Management/Analgesics',
#  '/Apparel/Jewelry',
#  '/Hobbies & Leisure/Antiques & Collectibles/Memorabilia/Sports Memorabilia',
#  '/Travel & Tourism/Cruises & Cruise Services',
#  '/Apparel/Clothing/Underwear',
#  '/Business & Industrial/Building Construction & Maintenance/HVAC & Climate Control/HVAC Service & Repair',
#  '/Finance/Credit & Lending/Credit Reports & Reporting Services',
#  '/Health/Pharmacy',
#  '/Business & Industrial/Business Management/Human Resources/Payroll Services',
#  '/Home & Garden/Bedding & Linens/Blankets & Bedspreads',
#  '/Finance/Insurance/Vehicle Insurance/Car Insurance',
#  '/Law & Government/Emergency Services/Roadside Assistance & Emergency Road Services',
#  '/Apparel/Clothing/Pants, Jeans & Trousers',
#  '/Finance/Credit & Lending/Credit Reports & Reporting Services',
#  '/Business & Industrial/Business Management/E-Commerce',
#  '/Health/Health Conditions & Concerns/Ear, Nose & Throat/Hearing Loss/Hearing Assistance Products/Hearing Aids & Accessories',
#  '/Business & Industrial/Building Construction & Maintenance/Building Materials & Supplies/Doors & Windows/Windows/Window Repair',
#  '/Finance/Insurance/Vehicle Insurance/Car Insurance',
#  '/Family & Community/Romance & Relationships/Dating & Marriage Matching',
#  '/Business & Industrial/Building Construction & Maintenance/Plumbing',
#  '/Health/Medical Devices, Equipment & Supplies/Medical Compression Garments & Stockings',
#  '/Apparel/Footwear/Footwear Accessories',
#  '/Computers & Consumer Electronics/Consumer Electronics/Wireless Devices/Bluetooth Wireless Accessories & Devices',
#  '/Internet & Telecom/Teleconferencing',
#  '/Finance/Credit & Lending/Loans/Personal Lending & Borrowing/Personal Loans & Lines of Credit',
#  '/Home & Garden/Home Appliances/Floor Cleaners & Accessories/Vacuum Cleaners & Accessories',
#  '/Travel & Tourism/Accommodations/Hotels, Motels & Resorts/Resorts/Resort Packages',
#  '/Hobbies & Leisure/Gardening/Trees, Plants & Shrubs',
#  '/Home & Garden/Home Furniture/Kitchen & Dining Room Furniture',
#  '/Finance/Financial Planning & Management/Retirement & Pension Planning',
#  '/Finance/Accounting & Auditing/Tax Preparation & Planning',
#  '/Family & Community/Romance & Relationships/Divorce & Separation/Online Divorce',
#  '/Jobs & Education/Jobs & Careers/Resume Writing/Resume & Cover Letter Samples & Templates',
#  '/Law & Government/Public Services/Public Utilities/Power & Electricity Services',
#  '/Travel & Tourism/Travel Documents/Passports & Passport Services',
#  '/Arts & Entertainment/Entertainment Industry/Film & TV Industry/TV Broadcasting/Internet TV',
#  '/Law & Government/Legal/Legal Forms & Kits',
#  '/Arts & Entertainment/Entertainment Industry/Film & TV Industry/TV Broadcasting/Digital TV',
#  '/Jobs & Education/Education & Training',
#  '/Travel & Tourism/Travel Documents/Passports & Passport Services',
#  '/Law & Government/Legal/Legal Forms & Kits',
#  '/Finance/Insurance/Vehicle Insurance/Car Insurance',
#  '/Law & Government/Public Services/Public Utilities/Power & Electricity Services',
#  '/Business & Industrial/Security Equipment & Services/Surveillance Equipment/Security Cameras',
#  '/Travel & Tourism/Air Travel/Airline Tickets, Fares & Flights',
#  '/Vehicles/Motor Vehicles/Cars & Trucks/Microcars & City Cars',
#  '/Internet & Telecom/Internet/Email & Messaging',
#  '/Arts & Entertainment/Entertainment Industry/Film & TV Industry/TV Broadcasting/Internet TV',
#  '/Arts & Entertainment/Sports Entertainment',
#  '/Internet & Telecom/Telephony/Mobile Phones & Accessories/Mobile Phones',
#  '/Computers & Consumer Electronics/Computers/Software/Business & Productivity Software/Business Management Software/Data Management Software',
#  '/Apparel/Footwear/Athletic Shoes',
#  '/Arts & Entertainment/Sports Entertainment',
#  '/Internet & Telecom/Internet/Email & Messaging',
#  '/Business & Industrial/Business Management/E-Commerce',
#  '/Law & Government/Legal/Legal Forms & Kits',
#  '/Hobbies & Leisure/Toys & Games/Games/Video Games, Consoles & Accessories/Computer & Video Games',
#  '/Home & Garden/Home Appliances/Major Kitchen Appliances/Refrigerators & Freezers']

# %%
# no_slash is a function that takes a list (l) as an argument
def no_slash(l):
    #return_value is a container for the desired output
    return_value = []
    # iterating over the list
    for i in l:
        #appending the arrays created by Python's built-in ().split function to my container 
        return_value.append(i.split('/')[1:])
    # returning the desired output
    return return_value

# %% [markdown]
# ## Array → Pandas Dataframe ##
# Using the no_slash function I will create a new list called taxonomy_array. From that list, I create a new dataframe called array_df, setting the columns names to levels 1-6 (l1, l2, etc.).
#
# Filtering out the NaN values in taxonomy_list was essential to transforming the product and services codes, as Python's ().split function breaks when encountering NaN values. As the new array_df is no longer correctly offset by the NaN values, I decided to edit this part in spreadsheets.

# %%
taxonomy_array = no_slash(taxonomy_list)
array_df = pd.DataFrame(taxonomy_array, columns = ['l1','l2','l3','l4','l5','l6'])
array_df
# Out:
#                                    l1                                     l2  \
# 0    Real Estate                       Real Estate Listings
# 1    Real Estate                       Real Estate Listings
# 2    Business & Industrial             Energy Industry
# 3    Real Estate                       Real Estate Listings
# 4    Occasions & Gifts                 Special Occasions
# 5    Travel & Tourism                  Transportation & Excursions
# 6    Vehicles                          Motor Vehicles
# 7    Finance                           Accounting & Auditing
# 8    Health                            Health Care Services
# 9    Internet & Telecom                Internet
# 10   Computers & Consumer Electronics  Computers
# 11   Apparel                           Clothing
# 12   None                              None
# 13   Jobs & Education                  Jobs & Careers
# 14   Real Estate                       Relocation & Household Moving
# 15   Computers & Consumer Electronics  Computers
# 16   Internet & Telecom                Internet
# 17   Home & Garden                     Yard, Garden & Patio
# 18   Home & Garden                     Yard, Garden & Patio
# 19   Home & Garden                     Home Appliances
# 20   Finance                           Investing
# 21   Finance                           Credit & Lending
# 22   Computers & Consumer Electronics  Computers
# 23   Home & Garden                     Home Appliances
# 24   Health                            Health Care Services
# 25   Travel & Tourism                  Luxury Travel
# 26   Home & Garden                     Kitchen & Dining
# 27   Apparel                           Clothing
# 28   Apparel                           Clothing
# 29   Food & Groceries                  Beverages
# 30   Business & Industrial             Business Management
# 31   Jobs & Education                  Education & Training
# 32   Business & Industrial             Business Management
# 33   Home & Garden                     Home Appliances
# 34   None                              None
# 35   Computers & Consumer Electronics  Computers
# 36   Finance                           Banking
# 37   Computers & Consumer Electronics  Computers
# 38   Health                            Health Conditions & Concerns
# 39   Health                            Health Care Services
# 40   Health                            Health Care Services
# 41   Home & Garden                     Home Furniture
# 42   Internet & Telecom                Teleconferencing
# 43   Internet & Telecom                Internet
# 44   Finance                           Credit & Lending
# 45   Law & Government                  Legal
# 46   Business & Industrial             Office
# 47   Home & Garden                     Home Furniture
# 48   Arts & Entertainment              Music & Audio
# 49   Health                            Health Care Services
# 50   Jobs & Education                  Education & Training
# 51   Finance                           Banking
# 52   Jobs & Education                  Education & Training
# 53   Computers & Consumer Electronics  Computers
# 54   Real Estate                       Property Development
# 55   Business & Industrial             Building Construction & Maintenance
# 56   Home & Garden                     Home Safety & Security
# 57   Finance                           Credit & Lending
# 58   Business & Industrial             Design & Engineering
# 59   Business & Industrial             Business Management
# 60   Apparel                           Clothing
# 61   Health                            Health Conditions & Concerns
# 62   Travel & Tourism                  Luggage & Travel Accessories
# 63   Computers & Consumer Electronics  Computers
# 64   Beauty & Personal Care            Make-Up & Cosmetics
# 65   Finance                           Banking
# 66   Jobs & Education                  Education & Training
# 67   Finance                           Credit & Lending
# 68   Real Estate                       Relocation & Household Moving
# 69   Home & Garden                     Kitchen & Dining
# 70   Arts & Entertainment              Music & Audio
# 71   Computers & Consumer Electronics  Computers
# 72   Business & Industrial             Industrial Goods & Manufacturing
# 73   Finance                           Credit & Lending
# 74   Home & Garden                     Home Appliances
# 75   Business & Industrial             Retail Trade
# 76   Finance                           Credit & Lending
# 77   Law & Government                  Legal
# 78   Finance                           Insurance
# 79   Sports & Fitness                  Fitness
# 80   Health                            Health Care Services
# 81   Home & Garden                     Yard, Garden & Patio
# 82   Finance                           Banking
# 83   Jobs & Education                  Education & Training
# 84   Finance                           Insurance
# 85   Vehicles                          Vehicle Parts & Accessories
# 86   Law & Government                  Legal
# 87   Computers & Consumer Electronics  Computers
# 88   Finance                           Credit & Lending
# 89   Home & Garden                     Kitchen & Dining
# 90   Computers & Consumer Electronics  Consumer Electronics
# 91   Apparel                           Clothing
# 92   Hobbies & Leisure                 Gardening
# 93   Home & Garden                     Kitchen & Dining
# 94   Vehicles                          Vehicle Donation & Removal
# 95   Computers & Consumer Electronics  Consumer Electronics
# 96   Business & Industrial             Business Management
# 97   Health                            Health Conditions & Concerns
# 98   Apparel                           Jewelry
# 99   Hobbies & Leisure                 Antiques & Collectibles
# 100  Travel & Tourism                  Cruises & Cruise Services
# 101  Apparel                           Clothing
# 102  Business & Industrial             Building Construction & Maintenance
# 103  Finance                           Credit & Lending
# 104  Health                            Pharmacy
# 105  Business & Industrial             Business Management
# 106  Home & Garden                     Bedding & Linens
# 107  Finance                           Insurance
# 108  Law & Government                  Emergency Services
# 109  Apparel                           Clothing
# 110  Finance                           Credit & Lending
# 111  Business & Industrial             Business Management
# 112  Health                            Health Conditions & Concerns
# 113  Business & Industrial             Building Construction & Maintenance
# 114  Finance                           Insurance
# 115  Family & Community                Romance & Relationships
# 116  Business & Industrial             Building Construction & Maintenance
# 117  Health                            Medical Devices, Equipment & Supplies
# 118  Apparel                           Footwear
# 119  Computers & Consumer Electronics  Consumer Electronics
# 120  Internet & Telecom                Teleconferencing
# 121  Finance                           Credit & Lending
# 122  Home & Garden                     Home Appliances
# 123  Travel & Tourism                  Accommodations
# 124  Hobbies & Leisure                 Gardening
# 125  Home & Garden                     Home Furniture
# 126  Finance                           Financial Planning & Management
# 127  Finance                           Accounting & Auditing
# 128  Family & Community                Romance & Relationships
# 129  Jobs & Education                  Jobs & Careers
# 130  Law & Government                  Public Services
# 131  Travel & Tourism                  Travel Documents
# 132  Arts & Entertainment              Entertainment Industry
# 133  Law & Government                  Legal
# 134  Arts & Entertainment              Entertainment Industry
# 135  Jobs & Education                  Education & Training
# 136  Travel & Tourism                  Travel Documents
# 137  Law & Government                  Legal
# 138  Finance                           Insurance
# 139  Law & Government                  Public Services
# 140  Business & Industrial             Security Equipment & Services
# 141  Travel & Tourism                  Air Travel
# 142  Vehicles                          Motor Vehicles
# 143  Internet & Telecom                Internet
# 144  Arts & Entertainment              Entertainment Industry
# 145  Arts & Entertainment              Sports Entertainment
# 146  Internet & Telecom                Telephony
# 147  Computers & Consumer Electronics  Computers
# 148  Apparel                           Footwear
# 149  Arts & Entertainment              Sports Entertainment
# 150  Internet & Telecom                Internet
# 151  Business & Industrial             Business Management
# 152  Law & Government                  Legal
# 153  Hobbies & Leisure                 Toys & Games
# 154  Home & Garden                     Home Appliances
#
#                                                     l3  \
# 0    Rental Listings
# 1    Rental Listings
# 2    Oil & Gas
# 3    Rental Listings
# 4    Funerals & Bereavement
# 5    Bus & Rail Services
# 6    Used Motor Vehicles
# 7    Tax Preparation & Planning
# 8    Laboratory Testing & Medical Diagnostic Services
# 9    Directories & Listings
# 10   Software
# 11   Women's Clothing
# 12   None
# 13   Job Listings
# 14   Storage Rental Services
# 15   Software
# 16   Internet Service Plans
# 17   Yard & Patio Furniture & Accessories
# 18   Yard & Patio Furniture & Accessories
# 19   Floor Cleaners & Accessories
# 20   Interest Free & Tax-Deferred Savings Accounts
# 21   Loans
# 22   Software
# 23   Laundry Room Appliances
# 24   Wellness Therapy & Massage
# 25   None
# 26   Kitchen Utensils & Gadgets
# 27   Sport Coats & Jackets
# 28   Suits & Business Attire
# 29   Non-Alcoholic Beverages
# 30   Advertising & Marketing
# 31   Training & Certification
# 32   Customer Support & Outreach
# 33   Major Kitchen Appliances
# 34   None
# 35   Software
# 36   Online Banking
# 37   Software
# 38   Mental Health
# 39   Geriatric & Aging Care Services
# 40   Vision Services
# 41   Bedroom Furniture
# 42   None
# 43   Internet Service Plans
# 44   Debt Management & Consolidation
# 45   Family Law
# 46   Office Furniture
# 47   Kitchen & Dining Room Furniture
# 48   Pop Music
# 49   Geriatric & Aging Care Services
# 50   Online Education & Degree Programs
# 51   Bank Accounts
# 52   Online Education & Degree Programs
# 53   Software
# 54   Commercial Property Development
# 55   Plumbing
# 56   None
# 57   Loans
# 58   Graphic Design
# 59   E-Commerce
# 60   Outerwear
# 61   Mental Health
# 62   Luggage
# 63   Computer Hardware
# 64   Concealer
# 65   Online Banking
# 66   Online Education & Degree Programs
# 67   Loans
# 68   Consumer Vehicle Shipping Services
# 69   Cookware & Cookware Sets
# 70   Pop Music
# 71   Computer Repair
# 72   Industrial Manufacturing
# 73   Debt Management & Consolidation
# 74   None
# 75   Merchant Services & Payment Systems
# 76   Debt Management & Consolidation
# 77   Attorneys & Law Firms
# 78   Health Insurance
# 79   Fitness Equipment & Accessories
# 80   Dentists & Dental Services
# 81   Yard & Patio Furniture & Accessories
# 82   Online Banking
# 83   Colleges, Universities & Post-Secondary Education
# 84   Vehicle Insurance
# 85   Vehicle Tires & Tire Parts
# 86   Attorneys & Law Firms
# 87   Software
# 88   Credit Counseling
# 89   Plates & Serving Dishes
# 90   Consumer Electronic Accessories
# 91   Pants, Jeans & Trousers
# 92   Yard & Garden Accessories
# 93   Bakeware
# 94   None
# 95   Wireless Devices
# 96   Advertising & Marketing
# 97   Headache & Pain Management
# 98   None
# 99   Memorabilia
# 100  None
# 101  Underwear
# 102  HVAC & Climate Control
# 103  Credit Reports & Reporting Services
# 104  None
# 105  Human Resources
# 106  Blankets & Bedspreads
# 107  Vehicle Insurance
# 108  Roadside Assistance & Emergency Road Services
# 109  Pants, Jeans & Trousers
# 110  Credit Reports & Reporting Services
# 111  E-Commerce
# 112  Ear, Nose & Throat
# 113  Building Materials & Supplies
# 114  Vehicle Insurance
# 115  Dating & Marriage Matching
# 116  Plumbing
# 117  Medical Compression Garments & Stockings
# 118  Footwear Accessories
# 119  Wireless Devices
# 120  None
# 121  Loans
# 122  Floor Cleaners & Accessories
# 123  Hotels, Motels & Resorts
# 124  Trees, Plants & Shrubs
# 125  Kitchen & Dining Room Furniture
# 126  Retirement & Pension Planning
# 127  Tax Preparation & Planning
# 128  Divorce & Separation
# 129  Resume Writing
# 130  Public Utilities
# 131  Passports & Passport Services
# 132  Film & TV Industry
# 133  Legal Forms & Kits
# 134  Film & TV Industry
# 135  None
# 136  Passports & Passport Services
# 137  Legal Forms & Kits
# 138  Vehicle Insurance
# 139  Public Utilities
# 140  Surveillance Equipment
# 141  Airline Tickets, Fares & Flights
# 142  Cars & Trucks
# 143  Email & Messaging
# 144  Film & TV Industry
# 145  None
# 146  Mobile Phones & Accessories
# 147  Software
# 148  Athletic Shoes
# 149  None
# 150  Email & Messaging
# 151  E-Commerce
# 152  Legal Forms & Kits
# 153  Games
# 154  Major Kitchen Appliances
#
#                                                l4  \
# 0    Apartment Rentals
# 1    Apartment Rentals
# 2    Fuel
# 3    Apartment Rentals
# 4    None
# 5    Rail Services
# 6    None
# 7    None
# 8    None
# 9    Phone & Address Directories
# 10   Business & Productivity Software
# 11   Skirts
# 12   None
# 13   IT & Technical Jobs
# 14   None
# 15   Internet Software & Web Goodies
# 16   None
# 17   None
# 18   None
# 19   Vacuum Cleaners & Accessories
# 20   None
# 21   Personal Lending & Borrowing
# 22   Business & Productivity Software
# 23   Washers & Dryers
# 24   Massage & Relaxation Services
# 25   None
# 26   None
# 27   None
# 28   None
# 29   Tea
# 30   Internet Marketing
# 31   None
# 32   None
# 33   Refrigerators & Freezers
# 34   None
# 35   Business & Productivity Software
# 36   None
# 37   Business & Productivity Software
# 38   Mental Health Medications
# 39   Assisted Living Services
# 40   Eye Exams & Optometry
# 41   Clothing & Shoe Storage
# 42   None
# 43   None
# 44   None
# 45   Divorce Law
# 46   Task Chairs
# 47   Kitchen & Dining Room Tables
# 48   None
# 49   Retirement Homes & Senior Living Communities
# 50   None
# 51   None
# 52   None
# 53   Business & Productivity Software
# 54   None
# 55   Plumbing Fixtures
# 56   None
# 57   Home Loans & Mortgages
# 58   None
# 59   None
# 60   None
# 61   Mental Health Medications
# 62   Carry-On Bags
# 63   Gaming Computers
# 64   None
# 65   None
# 66   None
# 67   Bad Credit & No Credit Credit & Lending
# 68   None
# 69   Pots & Pans
# 70   None
# 71   Data Recovery
# 72   Industrial Cutting
# 73   None
# 74   None
# 75   None
# 76   None
# 77   None
# 78   None
# 79   Fitness & Weight Training Machines
# 80   Orthodontists & Orthodontic Services
# 81   None
# 82   None
# 83   Graduate Programs
# 84   Car Insurance
# 85   None
# 86   None
# 87   Software Utilities
# 88   None
# 89   None
# 90   Batteries & Chargers
# 91   None
# 92   None
# 93   None
# 94   None
# 95   None
# 96   Internet Marketing
# 97   Analgesics
# 98   None
# 99   Sports Memorabilia
# 100  None
# 101  None
# 102  HVAC Service & Repair
# 103  None
# 104  None
# 105  Payroll Services
# 106  None
# 107  Car Insurance
# 108  None
# 109  None
# 110  None
# 111  None
# 112  Hearing Loss
# 113  Doors & Windows
# 114  Car Insurance
# 115  None
# 116  None
# 117  None
# 118  None
# 119  Bluetooth Wireless Accessories & Devices
# 120  None
# 121  Personal Lending & Borrowing
# 122  Vacuum Cleaners & Accessories
# 123  Resorts
# 124  None
# 125  None
# 126  None
# 127  None
# 128  Online Divorce
# 129  Resume & Cover Letter Samples & Templates
# 130  Power & Electricity Services
# 131  None
# 132  TV Broadcasting
# 133  None
# 134  TV Broadcasting
# 135  None
# 136  None
# 137  None
# 138  Car Insurance
# 139  Power & Electricity Services
# 140  Security Cameras
# 141  None
# 142  Microcars & City Cars
# 143  None
# 144  TV Broadcasting
# 145  None
# 146  Mobile Phones
# 147  Business & Productivity Software
# 148  None
# 149  None
# 150  None
# 151  None
# 152  None
# 153  Video Games, Consoles & Accessories
# 154  Refrigerators & Freezers
#
#                                    l5  \
# 0    None
# 1    None
# 2    Natural Gas
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# 10   Accounting & Financial Software
# 11   None
# 12   None
# 13   None
# 14   None
# 15   Network Security Software
# 16   None
# 17   None
# 18   None
# 19   None
# 20   None
# 21   Personal Loans & Lines of Credit
# 22   Business Management Software
# 23   None
# 24   None
# 25   None
# 26   None
# 27   None
# 28   None
# 29   None
# 30   None
# 31   None
# 32   None
# 33   None
# 34   None
# 35   Accounting & Financial Software
# 36   None
# 37   Accounting & Financial Software
# 38   Anxiety-Relief Medications
# 39   None
# 40   None
# 41   None
# 42   None
# 43   None
# 44   None
# 45   None
# 46   None
# 47   None
# 48   None
# 49   None
# 50   None
# 51   None
# 52   None
# 53   Business Management Software
# 54   None
# 55   Bathroom Fixtures
# 56   None
# 57   None
# 58   None
# 59   None
# 60   None
# 61   Anxiety-Relief Medications
# 62   None
# 63   None
# 64   None
# 65   None
# 66   None
# 67   None
# 68   None
# 69   None
# 70   None
# 71   None
# 72   None
# 73   None
# 74   None
# 75   None
# 76   None
# 77   None
# 78   None
# 79   Treadmills
# 80   None
# 81   None
# 82   None
# 83   MBA Programs
# 84   None
# 85   None
# 86   None
# 87   None
# 88   None
# 89   None
# 90   None
# 91   None
# 92   None
# 93   None
# 94   None
# 95   None
# 96   None
# 97   None
# 98   None
# 99   None
# 100  None
# 101  None
# 102  None
# 103  None
# 104  None
# 105  None
# 106  None
# 107  None
# 108  None
# 109  None
# 110  None
# 111  None
# 112  Hearing Assistance Products
# 113  Windows
# 114  None
# 115  None
# 116  None
# 117  None
# 118  None
# 119  None
# 120  None
# 121  Personal Loans & Lines of Credit
# 122  None
# 123  Resort Packages
# 124  None
# 125  None
# 126  None
# 127  None
# 128  None
# 129  None
# 130  None
# 131  None
# 132  Internet TV
# 133  None
# 134  Digital TV
# 135  None
# 136  None
# 137  None
# 138  None
# 139  None
# 140  None
# 141  None
# 142  None
# 143  None
# 144  Internet TV
# 145  None
# 146  None
# 147  Business Management Software
# 148  None
# 149  None
# 150  None
# 151  None
# 152  None
# 153  Computer & Video Games
# 154  None
#
#                                            l6
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# 10   None
# 11   None
# 12   None
# 13   None
# 14   None
# 15   Anti-Virus Software
# 16   None
# 17   None
# 18   None
# 19   None
# 20   None
# 21   None
# 22   Customer Service & Support Software
# 23   None
# 24   None
# 25   None
# 26   None
# 27   None
# 28   None
# 29   None
# 30   None
# 31   None
# 32   None
# 33   None
# 34   None
# 35   None
# 36   None
# 37   Time Management & Time Tracking Software
# 38   None
# 39   None
# 40   None
# 41   None
# 42   None
# 43   None
# 44   None
# 45   None
# 46   None
# 47   None
# 48   None
# 49   None
# 50   None
# 51   None
# 52   None
# 53
# 54   None
# 55   Bathtubs
# 56   None
# 57   None
# 58   None
# 59   None
# 60   None
# 61   None
# 62   None
# 63   None
# 64   None
# 65   None
# 66   None
# 67   None
# 68   None
# 69   None
# 70   None
# 71   None
# 72   None
# 73   None
# 74   None
# 75   None
# 76   None
# 77   None
# 78   None
# 79   None
# 80   None
# 81   None
# 82   None
# 83   None
# 84   None
# 85   None
# 86   None
# 87   None
# 88   None
# 89   None
# 90   None
# 91   None
# 92   None
# 93   None
# 94   None
# 95   None
# 96   None
# 97   None
# 98   None
# 99   None
# 100  None
# 101  None
# 102  None
# 103  None
# 104  None
# 105  None
# 106  None
# 107  None
# 108  None
# 109  None
# 110  None
# 111  None
# 112  Hearing Aids & Accessories
# 113  Window Repair
# 114  None
# 115  None
# 116  None
# 117  None
# 118  None
# 119  None
# 120  None
# 121  None
# 122  None
# 123  None
# 124  None
# 125  None
# 126  None
# 127  None
# 128  None
# 129  None
# 130  None
# 131  None
# 132  None
# 133  None
# 134  None
# 135  None
# 136  None
# 137  None
# 138  None
# 139  None
# 140  None
# 141  None
# 142  None
# 143  None
# 144  None
# 145  None
# 146  None
# 147  Data Management Software
# 148  None
# 149  None
# 150  None
# 151  None
# 152  None
# 153  None
# 154  None

# %%
'''
array_df.to_excel('array_df.xlsx')
'''

# %% [markdown]
# ## The final document ##

# %%
final_df = pd.read_excel('THED_level_codes.xlsx',
                           # the kwarg 'index_col' allows me to retain multiindexing across pandas & spreadsheets
                          index_col=[0,1])
# reapplying .sort_index function to correct and re-sort any categorical errors fixed using the spreadsheet
final_df = final_df.sort_index()
# filtering to show 
final_df = final_df.filter(items = ['query', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6'])
final_df
# Out:
#                                                                                                                                                                                                                                                                                                                    query  \
# language search intent
# DE       Commercial     privatverkauf wohnung
#          Commercial     wohnungsvermietung privat
#          Informational  aktueller heizöl tagespreis
#          Informational  mieter für wohnung gesucht
#          Informational  trauertexte für beileidskarten
#          Informational  zugverbindungen von nach
#          Navigational   autohandel gebrauchtwagen
#          Navigational   steuererklärung formular
#          Navigational   pcr test in meiner nähe
#          Navigational   das örtliche telefonnummer
# EN       Commercial     ap automation software
#          Commercial     purple maxi skirt
#          Commercial     top consulting firms
#          Commercial     best online it schools
#          Commercial     vehicle self storage
#          Commercial     antivirus software trial
#          Commercial     los angeles business internet providers
#          Commercial     outdoor rug stripes
#          Commercial     patio furniture set
#          Commercial     vacuum cleaners
#          Commercial     best online savings account interest rates
#          Commercial     personal loans
#          Commercial     customer data support platform
#          Commercial     lg frontload stainless steel
#          Commercial     massage therapist profiles
#          Commercial     luxury travel companies
#          Commercial     voyage dinnerware
#          Commercial     leather aviator jackets for men
#          Commercial     hugo boss suits
#          Commercial     bigelow raspberry tea
#          Commercial     digital marketing services online
#          Commercial     online certification programs
#          Commercial     best crm software for hotels
#          Commercial     whirlpool 36 in french door refrigerator
#          Commercial     accredited online college degree programs
#          Commercial     best payroll software
#          Commercial     sign up for bank account online
#          Commercial     work timesheet app
#          Commercial     anxiety meds without rx
#          Commercial     assisted living lafayette
#          Commercial     who accepts davis vision
#          Commercial     belt racks for closets
#          Commercial     video conference services
#          Commercial     los angeles business internet
#          Commercial     bad debt consolidation
#          Commercial     divorce attorney
#          Commercial     ergonomic office chair
#          Commercial     dining table pad covers
#          Commercial     juice mp3
#          Commercial     senior living
#          Commercial     online mba programs for international students
#          Commercial     small business bank account
#          Commercial     accredited online degrees
#          Commercial     small business management software
#          Commercial     commercial patio furniture
#          Commercial     walk in bath prices
#          Commercial     best security system for home
#          Commercial     mortgage preapproval
#          Commercial     logo maker
#          Commercial     wordpress ecommerce
#          Commercial     cobalt blue jumpsuit
#          Commercial     xanax canadian pharmacy
#          Commercial     carry on luggage with wheels
#          Commercial     best gaming laptop
#          Commercial     it cosmetics concealer
#          Commercial     best online savings accounts
#          Commercial     compare online college degrees
#          Commercial     online money lenders for bad credit
#          Commercial     auto moving company
#          Commercial     stainless steel pan
#          Commercial     juice mp3
#          Commercial     data recovery service
#          Commercial     rebar cutting tools
#          Commercial     best tax debt relief services
#          Commercial     air purifiers
#          Commercial     payment processing system
#          Commercial     debt reduction services
#          Commercial     cheap lawyers
#          Commercial     individual dental and vision insurance
#          Commercial     shop bowflex treadmill
#          Commercial     dental implants
#          Commercial     54 outdoor bench cushion
#          Commercial     bank account online
#          Commercial     best mba programs
#          Commercial     auto insurance companies
#          Commercial     who has best tire deals
#          Commercial     looking for a malpractice lawyer
#          Commercial     pdf reader
#          Commercial     bankruptcy credit counseling
#          Commercial     dinnerware birds
#          Commercial     batteries for stereo
#          Commercial     white casual pants
#          Commercial     garden hose
#          Commercial     pastry board marble
#          Commercial     car donation
#          Informational  how does alexa work
#          Informational  online advertising earn money
#          Informational  when your lower back hurts
#          Informational  tornado in nc
#          Informational  keto diet food list pdf
#          Informational  gout symtoms
#          Informational  the size of a cell is limited by the ____.
#          Informational  current chicago lakefront temperature
#          Informational  what you need to know about flipping houses
#          Informational  how long does heroin stay in your system
#          Informational  will i qualify for a mortgage
#          Informational  digital transformation model
#          Informational  what causes low white cell count
#          Informational  heart attacksymptoms
#          Informational  math
#          Informational  what should my sugar level be
#          Informational  is the post office open today
#          Informational  pros and cons of annuities
#          Informational  what are symptoms of ms disease
#          Informational  10 day forecast kent
#          Informational  why does a company go public
#          Informational  how do i lease a car
#          Informational  what causes tremors in hands
#          Informational  pictures of bed bug bits
#          Informational  what time does target close
#          Informational  how do you treat afib
#          Informational  what is normal cholestrol level
#          Informational  how to remove red wine stain
#          Informational  what is amyloidosis symptoms
#          Informational  what helps severe constipation
#          Informational  how can i make money quick
#          Informational  how low is too low for bp
#          Informational  what causes low red cell count
#          Informational  nasdaq etf
#          Informational  do i need to take consent of my husband to take my 8year old son abroad for a job  & as i have filed for  a divorce & its in process
#          Informational  do credit cards work
#          Informational  stomach pains chart
#          Informational  what is the temperature in las vegas in mid may
#          Informational  does kaiser cover hearing aids
#          Informational  temperature in tampa
#          Informational  is it better to own or lease a car
#          Informational  29829 weather
#          Informational  then compute : payback period, and decision if the policy of accepting project is &lt; 1.5 year. accounting rate of return decision if both projects are independent. net present value decision if both projects are independent. benefit cost ratio decision if both projects are independent.
#          Informational  does norco make you gain weight
#          Informational  san pedro cactus
#          Informational  Five Day Precipitation Forecast Map Tennessee
#          Informational  where is my stimulas check
#          Informational  is there
#          Informational  how depressed are you quiz
#          Informational  options trading beginners
#          Informational  temperature in cancun in July
#          Informational  what is a squamous cell
#          Informational  volunteer organizations
#          Informational  how to make amphetamine sulphate at home
# ...
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     Anti-Virus Software
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     Customer Service & Support Software
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     Time Management & Time Tracking Software
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     Bathtubs
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          NEI            NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  Hearing Aids & Accessories
#          Transactional  Window Repair
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
# ES       Commercial     NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN
# JA       Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Commercial     NaN
#          Informational  NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Transactional  Data Management Software
# NEI      Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          Informational  NaN
#          NEI            NaN
# PT       Commercial     NaN
#          Navigational   NaN
#          Navigational   NaN
#          Navigational   NaN
#          Transactional  NaN
#          Transactional  NaN
#          Transactional  NaN

# %% [markdown]
# # Part 1 Summary
# Using pandas multiindexing, I organized queries into groups by setting their indexes to language and search intent. I created new columns named l1-l6 that represent the progressively specific levels of their associated Google Product Taxonomy.
#
# As I wanted to create a usable document to be able to explore the commonalities in the data, I used the document to answer 2 self-imposed questions.
#
# *what is the top search intent for each language?* ***and** *what is the top L1 (highest level Google Product Taxonomy) for each langauge?*
#
# ## Language
# **81.2%** of queries were in **English**
# **5.2%** were in **Spanish**
# **4%** were in **German**
# **4%** were in **Japanese**
# **2.8%** were in **Portuguese**
# and another **2.8%** of queries were of **undeterminable language** by query alone.
#
# ## Search Intent
# **37.6%** of queries were of **Commercial** search intent
# **37.6%** were **Informational**
# **9.6%** were **Navigational**
# **14.4** were **Transactional**
# and **0.8%** **needed more information** to identify.
#
# ## Top Search Intents by Language
# In the cells below I used filtering and some built-in functions to find the top search intent by langauge.
#
# English: Commercial intent comprised **41.9%** of queries.
# Spanish: Transactional intent comprised **38.5%** of queries.
# German: Informational & Navigational each comprised **40%** of queries
# Japanese: Commercial intent comprised **50%** of Japanese queries.
# Portuguese: Navigational & Transactional intent each comprised **42.9%** queries.

# %%
# the kwarg 'level' allows me to apply the .size() function to the indexes to find the most frequently appearing search intent
# for each language
final_df.groupby(level=[0,1]).size()
# Out:
# language  search intent
# DE        Commercial       2
#           Informational    4
#           Navigational     4
# EN        Commercial       85
#           Informational    79
#           NEI              1
#           Navigational     11
#           Transactional    27
# ES        Commercial       1
#           Informational    4
#           Navigational     3
#           Transactional    5
# JA        Commercial       5
#           Informational    1
#           Navigational     3
#           Transactional    1
# NEI       Informational    6
#           NEI              1
# PT        Commercial       1
#           Navigational     3
#           Transactional    3
# dtype: int64

# %%
# Pandas' .xs() function takes multiindex labels as an argument and filters the dataframe by those labels
# Each expression represents the amount of queries containing the top search intent divided by the total amount 
# of queries in that language
print(
'\n English: ', len(final_df.xs(('EN', 'Commercial'))) / len(final_df.xs('EN')),
'\n Spanish: ', len(final_df.xs(('ES', 'Transactional'))) / len(final_df.xs('ES')),
'\n German: ', len(final_df.xs(('DE', 'Informational'))) / len(final_df.xs('DE')),
'\n Japanese: ', len(final_df.xs(('JA', 'Commercial'))) / len(final_df.xs('JA')),
'\n Portuguese: ', len(final_df.xs(('PT', 'Transactional'))) / len(final_df.xs('PT')))
# Out:
#  English:  0.4187192118226601
#  Spanish:  0.38461538461538464
#  German:  0.4
#  Japanese:  0.5
#  Portuguese:  0.42857142857142855

# %% [markdown]
# ## Top L1 by Language
#
# English: Finance
# Spanish: Law & Government
# German: Real Estate
# Japanese: Internet & Telecom
# Portuguese: Apparel

# %%
# Filtering final_df by each langauge.
german = final_df.xs('DE')
english = final_df.xs('EN')
spanish = final_df.xs('ES')
japanese = final_df.xs('JA')
portuguese = final_df.xs('PT')

# applying the built-in functions .value_count() and .idxmax() to find the most frequently appearing string in the 'L1' column.
print('Top L1 per language: ' +
'\n English: ' + english['L1'].value_counts().idxmax(),
'\n Spanish: ' + spanish['L1'].value_counts().idxmax(),
'\n German: ' + german['L1'].value_counts().idxmax(),
'\n Japanese: ' + japanese['L1'].value_counts().idxmax(),
'\n Portuguese: ' + portuguese['L1'].value_counts().idxmax())
# Out:
# Top L1 per language:
#  English: Finance
#  Spanish: Law & Government
#  German: Real Estate
#  Japanese: Internet & Telecom
#  Portuguese: Apparel

# %% [markdown]
# _______________________
# # Part 2: Result Quality Evaluation #
# Create a rubric to score the pairs of queries and article titles.
#
# Not all bad matches are created equally. Make sure that your rubric is granular enough to distinguish
# between multiple levels of “bad”. Label the pairs according to your scoring rubric and summarize the
# evaluation results.
#
# ## Scoring Rubric ##
# I created this scoring rubric to classify these pairs by how related the query and user intent are to the title of the article. I also took into account how likely a user is to be satified by the information in the article or if they would have to look elsewhere for more relevant information.
#
# **Very Poor** - Article is irrelevant or possibly matching with non-topic keyword or synonyms. A user would likely skip this article.
# **Poor** - Article title is only slightly related to the keyword. A user would likely skip this article.
# **Less Acceptable** - The article offers broader or more specific information than queried. A user may or may not click this article.
# **Acceptable** - Article title fits the topic of the keyword and satisfies user intent. This rating is for an article where the queried information exists in the body text, but requires more effort to find.
# **Good** - Article satisfies user intent and fits the topic. This rating is for an immediately satifying article.

# %%
results_df = pd.read_excel('take-home_eval-data.xlsx', sheet_name = 'Part 2 Results')
# filtering to exclude notes I took on the spreadsheet for reference
results_filtered_df = results_df.filter(items = ['keyword', 'title', 'rating'])
# sorting alphabetically by rating to group like ratings for readability
results_filtered_df.sort_values(by=['rating'])
# Out:
#                                          keyword  \
# 31  distance learning mba online
# 12  ninja blender
# 6   what should my sugar level be
# 34  single moms grants
# 8   best cruise packages
# 19  social media marketing
# 9   transfer money from australia to new zealand
# 16  custom chef hat
# 5   moving overseas shipping
# 25  travel jewelry case
# 32  car accident attorney
# 7   sleepwell mattress buy online
# 24  pulmonary fibrosis life expectancy
# 22  best rated dentist near me
# 21  list of brain cancers
# 20  cheap bike insurance
# 0   vacation packages
# 17  new zealand honeymoon
# 14  physician assistant career
# 13  how much do truckers earn
# 11  allergy mattress covers
# 10  download and install netflix
# 15  myrtle beach lodging
# 18  smart workout equipment
# 33  pros and cons of annuities
# 1   senior living
# 2   building maintenance services
# 30  cheap domain names
# 29  machine learning online course
# 26  crime clean up
# 27  healthcare equipment
# 3   nutritional value almonds
# 4   good mom jeans
# 23  nutritional supplements
# 28  insurance quotes
# 35  dark circle concealer
#
#                                                                                     title  \
# 31  10 of the Best MBA Programs
# 12  The Best Blenders for Home Use
# 6   What Is a Blood Glucose Level?
# 34  15 Helpful Financial Aid Grants for Single Mothers
# 8   10 Luxury Cruise Packages for Your Next Vacation
# 19  15 Businesses With a Great Social Media Presence
# 9   Best Platforms for Transferring Money Internationally
# 16  The Best Cookware for Every Cook
# 5   How to Ship a Vehicle
# 25  Best Luggage for All Your Travels
# 32  What Is the Best Way to Find a Lawyer After a Car Accident?
# 7   Best Bed Sheets for the Perfect Night's Sleep
# 24  3 Common Causes of Lung Inflammation
# 22  10 Facts About Dental Insurance
# 21  Pancreatic Cancer: Everything You Need to Know
# 20  What Are the 5 Different Types of Insurance?
# 0   4 Reasons to Start Investing in Travel and Hospitality
# 17  The Real Reasons New Zealand Is Beating COVID-19
# 14  Doctors From Around The World Share The Weird Things They Have Encountered On The Job
# 13  How to Calculate Your Retirement Income
# 11  How Often Should You Wash Your Bed Sheets?
# 10  The Best Scary Movies on Netflix
# 15  Tips for Buying a Beach Home
# 18  What to Know About Buying a Smart Car
# 33  Pros And Cons Of Genetically Modified Foods
# 1   What Are Some Non-Living Things in the Desert?
# 2   Can an Extended Service Plan Help You Save on Car Repairs?
# 30  How to Find the Origins of Your Last Name
# 29  Where to Find Used Sewing Machines Online
# 26  Helpful Cleaning Tips to Get Your Home Sparkling
# 27  How to Store Farm Equipment
# 3   The Cost of Starting a Food Truck
# 4   Everything You Need to Know About Mother of the Bride Dresses
# 23  The Major Health Hazards of Fast Food
# 28  10 Inspiring Quotes from History
# 35  Dark Internet: The Origins of the Dark Web
#
#              rating
# 31  Acceptable
# 12  Acceptable
# 6   Acceptable
# 34  Good
# 8   Less Acceptable
# 19  Less Acceptable
# 9   Less Acceptable
# 16  Less Acceptable
# 5   Less Acceptable
# 25  Less Acceptable
# 32  Less Acceptable
# 7   Less Acceptable
# 24  Poor
# 22  Poor
# 21  Poor
# 20  Poor
# 0   Poor
# 17  Poor
# 14  Poor
# 13  Poor
# 11  Poor
# 10  Poor
# 15  Poor
# 18  Very Poor
# 33  Very Poor
# 1   Very Poor
# 2   Very Poor
# 30  Very Poor
# 29  Very Poor
# 26  Very Poor
# 27  Very Poor
# 3   Very Poor
# 4   Very Poor
# 23  Very Poor
# 28  Very Poor
# 35  Very Poor

# %% [markdown]
# # Part 2 Summary #
# ### Relevant Overall Group ##
# The Relevant Overall Group, containing the scores **Less Acceptable**, **Acceptable**, and **Good**. This group contained **32.4%** of the keyword and title pairs. On the Less Acceptable end of the scale, a user is only *somewhat* likely to click the article. The higher the score, the more likely a user would be to click that article and have it serve their intent.
#
# Matches with scores in the Relevant Overall Group should be fairly likely to be clicked on.
#
# ### Irrelevant Group ###
# The Irrelevant Group contained the **Very Poor** and **Poor** scores. This group contained **67.6%** of the keyword and title pairs. This group is distinguished from the Relevant Overall Group by the high likelihood of users skipping these articles entirely.
#
# **Matches in the Irrelevant Group risk users having a frustrating search experience by showing low quality results.** They would be unlikely to be clicked on. However, these matches could be insightful for editorial topic generation.

# %% [markdown]
# ________________________________________________
# # Part 3: Translation Evaluation #
#  Rate the quality of the translations.
#
# ## Japanese text translated to English
#
# * Do the English translations capture the topic and user intent?

# %%
translations_df = pd.read_excel('take-home_eval-data.xlsx', sheet_name = 'Part 3 Translations')
translations_df.iloc[:18]
# Out:
#                input                                         translation  \
# 0   高 性能 ノート パソコン 激安  High -performance laptops discount
# 1   太陽 光 発電 ソーラー パネル  Solar power generation solar panel
# 2   階段 昇降機            Staircase elevator
# 3   老人 ホーム            Nursing home
# 4   型 落ち デスクトップ パソコン  Dropped desktop PC
# 5   ローレックス 買い取り 価格    Lawx purchase price
# 6   zoom アプリ 無料       ZOOM app free
# 7   介護 付き 有料 老人 ホーム   Paid nursing home with nursing care
# 8   スマホ で 監視 防犯 カメラ   Surveillance and security camera with a smartphone
# 9   ローレックス 買取 相場      Lawx purchase price
# 10  ダイハツ 軽 自動車 新車     Daihatsu light car new car
# 11  介護 付 有料 老人 ホーム    Paid nursing home with nursing care
# 12  募集 求人             Recruitment
# 13  老人 ホーム 料金 表       Elderly home price list
# 14  探偵 浮気 調査          Detective cheating survey
# 15  求人 掲載 料金 比較       Job posting fee comparison
# 16  新品 格安 ノート パソコン    New cheap laptop
# 17  hp 法人 向け          For HP corporations
#
#    captures topic captures user intent
# 0   True           True
# 1   True           True
# 2   True           True
# 3   True           True
# 4   False          False
# 5   False          False
# 6   True           True
# 7   True           True
# 8   True           True
# 9   False          False
# 10  True           True
# 11  True           True
# 12  False          False
# 13  True           True
# 14  True           True
# 15  True           True
# 16  True           True
# 17  False          False

# %% [markdown]
# ## Summary ##
# ### Japanese → English ###
# In general, the translations were acceptable and if they retained their topic they also retained their user intent.
#
# **72.2%** of inputs **retained** their topic and user intent.
# **27.8%** of inputs **did not retain** topic or user intent.
#
# For the **27.8%** of inputs that **did not retain their topic or user intent**, there are 3 reasons why.
#
# **40%** were affected by **polysemy**, the many possible meanings for a word or phrase.
# **40%** were mistranslated **katakana words.**
# **20%** were mistranslated due to **spacing.**
#
# ### 1. Polysemy ###
# At **index 17**, translating 'hp 法人 向け'(eichipi- houjinmuke) to 'For HP corporation' introduces ambiguity not present in the Japanese input. The original input expresses the user intent of somebody seeking to purchase HP laptops in bulk at a reduced price per unit as part of a B2B sale. This translation captures the 'for' from '向け' (muke) and '法人' (koujin) kind of blends with 'HP' to from 'HP corporations.' Spacing within the compound word '法人向け', likely exacerbates this problem.
#
# At **index 12**, translating '募集 求人' to 'Recruitment' condenses both Japanese words into one English word. Semantic aspects of both words include the idea of recruitment, but the translated query 'Recruitment' does not capture the intent of looking for job postings. This was likely unaffected by spacing. Though these words are used in close proximity to each other, '募集求人' is not a compound word.
#
# ### 2. Katakana mistranslations ###
# At **index 5 and 9**, 'ローレックス' (ro-rekkusu) is mistranslated as 'lawx.' The correct translation should be Rolex, as in the luxury watch brand.
#
# Katakana is a Japanese writing system that is mostly used for foreign words. Katakana characters represent a sylabble comprised of a consonant and vowel pair. The mistranslation at **index 5 and 9** is unusual because the derivation of the character 'x' in 'lawx' suggests the algorith is breaking the katakana characters into smaller phonemes and excluding the /r/ sound to create 'lawx.' This is a somewhat sophisticated mistake. In the case of an insufficient corpus such that 'ローレックス' would not be translated to 'Rolex', a more expected mistranslation would be something like 'lawlex' or 'lawrex.'
#
# ### 3. Spacing ###
# There are half-width spaces between and within words in every query on this list. These spaces can cause issues with machine translation.
#
# Seeing half-width spaces suggests that these are keywords suggested to a user by Google, rather than ones input entirely by the user. This is because Japanese uses full-width spaces and only between sentences or clauses. It's been [documented](https://www.humblebunny.com/multilingual-seo-japanese-research/) that when Google suggests keywords they insert these half-width spaces between *words.* A suggested keyword is functionally identical to the same query that is typed without half-width spaces, but insertion of these spaces often breaks up compound words and could lead to mistranlsations.
#
# At **index 4** for example, the suggested query [型 落ち デスクトップ パソコン](https://www.google.com/search?q=%E5%9E%8B+%E8%90%BD%E3%81%A1+%E3%83%87%E3%82%B9%E3%82%AF%E3%83%88%E3%83%83%E3%83%97+%E3%83%91%E3%82%BD%E3%82%B3%E3%83%B3&rlz=1C1FKPE_enUS965US965&sxsrf=ALiCzsbe6s4Vuwf1QzbUuwWCvL0Msp1Xjw%3A1656985137306&ei=MZbDYuGrEsTa9AOM_YXACg&ved=0ahUKEwihiIfUzuD4AhVELX0KHYx-AagQ4dUDCA8&uact=5&oq=%E5%9E%8B+%E8%90%BD%E3%81%A1+%E3%83%87%E3%82%B9%E3%82%AF%E3%83%88%E3%83%83%E3%83%97+%E3%83%91%E3%82%BD%E3%82%B3%E3%83%B3&gs_lcp=Cgdnd3Mtd2l6EAMyBAgjECc6BwgjEOoCECdKBAhBGABKBAhGGABQqQZYqQZgigloAXABeACAAT-IAT-SAQExmAEAoAEBoAECsAEKwAEB&sclient=gws-wiz) would return the same SERP as [型落ちデスクトップパソコン](https://www.google.com/search?q=%E5%9E%8B%E8%90%BD%E3%81%A1%E3%83%87%E3%82%B9%E3%82%AF%E3%83%88%E3%83%83%E3%83%97%E3%83%91%E3%82%BD%E3%82%B3%E3%83%B3&rlz=1C1FKPE_enUS965US965&sxsrf=ALiCzsYwss3acSViC2BP5n6GfJgytUZl0w%3A1656985726306&ei=fpjDYuehEvKG0PEPqsKU0AQ&ved=0ahUKEwjn2PTs0OD4AhVyAzQIHSohBUoQ4dUDCA8&uact=5&oq=%E5%9E%8B%E8%90%BD%E3%81%A1%E3%83%87%E3%82%B9%E3%82%AF%E3%83%88%E3%83%83%E3%83%97%E3%83%91%E3%82%BD%E3%82%B3%E3%83%B3&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAEIAEOgcIIxDqAhAnSgQIQRgASgQIRhgAUNQBWNQBYOYJaAFwAXgAgAE8iAE8kgEBMZgBAKABAaABArABCsABAQ&sclient=gws-wiz), but in this case the suggested keyword was mistranslated due to the insertion of spaces.
#
# ## Conclusions ##
# 1. Polysemic mistranslations comprised **40%** of mistranslations and [could point to a low quality corpus in the MT system used.](https://sienstranslation.com/en/blog/2020/12/23/most-frequent-errors-in-machine-translation/)
# 2. Katakana mistranslations also comprised **40%** of mistranslations, although both examples were of the same word mistranslated the same way. The deconstruction of katakana syllables into smaller phonemes was sophisticated in a way, but I would not expect a MT system trained on sufficient corpora to fail to translate 'Rolex.'
# 3. Spacing affected all the queries, but only **20%** were mistranslated *wholly* because of the insertion of half-width spaces. I expect that mistranslation due to spacing would be mitigated to an extent by the ideographic meaning of Kanji, the system of Japanese writing using Chinese ideographic characters.
#
# If this data were representative of a larger data set, nearly 30% would be mistranslated. **This would make for a poor user experience and risks user retention.**
#
# Mistranslations could be reduced by:
# 1. Improving or implementing [word sense disambiguation](http://www.scholarpedia.org/article/Word_sense_disambiguation) to reduce mistranslations due to polysemy.
# 2. Accounting for how suggested keywords differ from user generated keywords in regard to spacing.

# %% [markdown]
# ____________________________________
# # Part 3 continued #
#
# ## English text translated to Japanese
# * Are there grammatical errors? Would the Japanese translations seem awkward or otherwise not
#     make sense to a Japanese reader?

# %%
part3_df = translations_df.filter(items = ['input', 'translation'])
part3_df.iloc[18:]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               input  \
# 18  Tips for Buying a Beach Home
# 19  The Best Cookware for Every Cook
# 20  How Often Should You Wash Your Bed Sheets?
# 21  4 Reasons to Start Investing in Travel and Hospitality
# 22  5 Funny Quotes from History
# 23  Are you a frequent traveler? Do you head out of town every once in a blue moon? No matter how often you travel, quality luggage is a good investment. You need to be able to rely on your luggage to keep your belongings protected when you’re on the move. Broken zippers and seams are a pain no matter how often (or not) you’re in the airport.
# 24  The only thing that should hold you back from dining on these delicious sea critters is an allergy to shellfish. Otherwise, you might want to consider taking a weekend off to make a foodie trip to Australia. The king oysters found in the south-central Coffin Bay are huge, succulent and intensely flavorful. If you’d like to make a day or an evening of it, you can even join one of the many Coffin Bay oyster tours and dine on some of the freshest, tastiest seafood in the world. Oh, and wine is often included.
#
#                                                                                                                                                                                                                                               translation
# 18  ビーチの家を買うためのヒント
# 19  すべての料理人に最適な調理器具
# 20  どのくらいの頻度でベッドシートを洗う必要がありますか？
# 21  旅行とホスピタリティへの投資を開始する4つの理由
# 22  歴史からの5つの面白い引用
# 23  あなたは頻繁に旅行しますか？ あなたは青い月に一度町を出ますか？ あなたがどれほど頻繁に旅行しても、高品質の荷物は良い投資です。 移動中に荷物を保護するために、荷物に頼ることができる必要があります。 空港にどれだけ頻繁に（またはそうでなくても）、壊れたジッパーと縫い目は苦痛です。
# 24  これらのおいしい海の生き物で食事をするのを妨げる唯一のことは、貝に対するアレルギーです。 それ以外の場合は、オーストラリアへの食通旅行をするために週末を休むことを検討することをお勧めします。 コフィンベイの中央南部で見つかったキングオイスターは、巨大でジューシーで、非常に風味豊かです。 一日または夜を過ごしたい場合は、多くのコフィンベイオイスターツアーの1つに参加して、世界で最も新鮮でおいしいシーフードのいくつかで食事をすることもできます。 ああ、そしてワインがしばしば含まれています。

# %% [markdown]
# ## English → Japanese Summary ##
# I am not a native Japanese speaker, but there are no glaring grammatical errors that I can see in any of the translated Japanese. I believe that a Japanese reader would understand all of the translated article titles. However, some of the article text is awkward and may cause slight confusion.
#
# ### AMG Network Article Titles ###
# The translated article titles are all grammatically correct and retain their meaning. There are some phrases that might be optimized for better search visibility.
# * For instance at **index 18**, 'ビーチの家' (bi-chi no ie) meaning beach house is a broad query and returns all sorts of phrases relating to beaches and houses. Something like '海沿いの家' (umizoi no ie) meaning seaside house returns real estate listings and articles similar to the orginal AMG Network article.
# * At **index 20**, 'ベッドシート' (beddo shi-to) might be improved by using a more common synonym 'ベッドシーツ' (beddo shi-tsu).
#
# ### AMG Network Article Text ###
# Each article suffered from unique translation issues, but the translated text is all grammatically correct.
#
# The translated article text at **index 23** suffers mostly from **literal translation.** It also sounds a bit unnatural.
# * Repitition of the second person pronoun 'あなた' (anata) in the first 3 sentences in the example at index 23 sounds unnatural. In Japanaese it sounds more natural to omit the subject or topic of the sentence, only mentioning it if context would otherwise fail.
# * 'Once in a blue moon' is translated literally and the idiomatic meaning is lost in translation.
# * 'Pain' as in an annoyance is translated to '苦痛' (kutsuu) meaning anguish, which sounds bizzarely intense.
#
# The input article text at **index 24** contains long and wordy clauses that form complex sentences. Even so, I believe this is the better translated of the two texts. The translated text suffers from **ambiguity** created by translating certain English prases containing 'oyster' into katakana.
# * The translation of 'king oyster' to 'キングオイス' (kingu oisuta-) never connects the katakana spelling of the Englsh word 'oyster' to the more common Japanese word for oyster, which is 'カキ' (kaki). I think that it's very likely that a Japanese reader would infer from the context that this article is written about oysters, but it's not stated explicitly in the translation.
# * The translation of 'ああ' (aa) in this article may or may not convey the fun and informational tone of the input text. I don't often see 'ああ' (aa) in writing outside of dialog or personal correspondence. It could seem strange, but I can't say for sure.
#
# ## Conclusions ##
# **The translated article titles are acceptable**. From an SEO standpoint, they could be improved by researching synonymous keywords in the target language.
#
# The translated article text is clearly machine translated. It sounds unnatural in places, and at times it doesn't make sense. **Were the translated article text to go live it could risk repelling a readership.**
#
# Implementing an editorial style guide to improve the performance of machine translation would be worth exploring. Utilizing controlled langauge has been instrumental in creating documentation, manuals, and various other technical information that is easily machine translatable. I wonder if this could be achieved editorially as well.

# %% [markdown]
# ______________
# # Notes #
# ### Japanese → English ###
#
# 4. '型落ち' (kataochi) means out-of-production or an older model. This phrase was likely mistranslated due to spacing in the original query '型 落ち'. '型落ち" (kataochi) is formed from the word '型' (kata) meaning type, form, or standard and '落ち' (ochi) the noun stem of the verb '落ちる' (ochiru) which means to fall or to drop.
#
#
# 5. 'ローレックス' (ro-rekusu), is meant to represent the luxury watch brand Rolex.
#
#
# 9. See Note for index 5.
#
#
# 11. The queries at index 7 '介護 付き 有料 老人 ホーム' and index 11 '介護 付 有料 老人 ホーム' are identical except for the ommission of the hiragana character 'き' (ki) in query 11. The machine translation is still accuracte despite this due to the ideographic meaning of the character '付' which comes from the verb '付く' (tsuku) in this case.
#
#
# 12. The two words in this query are '募集' (boshuu) and '求人' (kyuujin). Both words refer to 'recruitment' of some kind. '募集' (boshuu) means recruitment by means of advertisement or solicitation, while '求人' (kyuujin) is a job listing. The translated query would return general informational content about recruitment, but not necessarily job listings.
#
#
# 14. Translating the query '探偵 浮気 調査'(tantei uwagi chousa) to 'detective cheating survey' retains the topic. However, the user intent is ambiguous as 'survey' can be interpreted as a data aquisition method. It can also mean 'survey' as in an examination or investigation. The English keyword 'survey' returns articles about extramarital detective work _citing_ surveys higher on the SERP, where 'investigation' might return pricing information about extramarital detective services. This semantic ambiguity exists in the Japanese word '調査' (chousa) as well.
#
#
# 17. In the query 'hp 法人 向け' (eichipi- houjinmuke), [' 法人 向け' (houjinmuke) means products or services targeted towards corprate organizations rather than individual consumers, usually with reduced a price per unit.](https://www.weblio.jp/content/%E6%B3%95%E4%BA%BA%E5%90%91%E3%81%91#:~:text=%E5%80%8B%E4%BA%BA%E3%81%A7%E3%81%AF%E3%81%AA%E3%81%8F%E6%B3%95%E4%BA%BA%E7%B5%84%E7%B9%94,%E3%81%A6%E3%81%84%E3%82%8B%E3%81%93%E3%81%A8%E3%81%8C%E5%A4%9A%E3%81%84%E3%80%82)
#
# ### English → Japanese ###
#
# 18. 'ビーチの家' (bi-chi no ie) is a suitable translation for (beach house). However, a synonym like '海辺の家' (umizoi no ie) could improve the precision of results as 'ビーチ' (bi-chi) is matching for articles containing tips for a beach lifestyle without much mention of real estate.
#
#
# 19. and 20. Both return relevant results. The use of the polite register in translation 20 seems conversational, and quite different from other Japanese queries I've seen while working on this assignment.
#
#
#
# 21. Though grammatically correct, this translated query didnt return precise results via the first SERP on Ask, Google, or Yahoo Japan. Precision was highest using Yahoo.com.
#
#
# 22.
#
#
# 23. The repetition of 'あなた' in the first three sentences sounds strange, as the syntactic subject or topic is often ommited. The idiomatic expression 'once in a blue moon' translates literally and won't make sense. 'Pain' gets translated literally as well and sounds intense, where 'inconvenient' may fit the tone better.
#
# 24. Though it is 5 sentences long, which is as many as the previous text has, it has longer and more complex sentences. Despite this, I believe it is the better translated of the two.

# %% [markdown]
#  ________________________________________________
# ## Additional resource gathering ##
# I met with Sasha on 6/23/22 after I had some time with the data. I asked for guidance on terminology that I was confused about regarding the terms search intent and user intent. I also recieved guidance on how granular I might make the low end my scoring rubric for part 2 of the assignment.
#
# I met with Sasha again on 6/30/22 and we discussed
